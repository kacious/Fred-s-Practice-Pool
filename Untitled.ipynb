# %%
import pandas as pd
s = pd.Series(['dd',2,3,4],[0,4,3,2])

# %%
s2 = pd.DataFrame(s)

# %%
s
# Out:
# 0    dd
# 4     2
# 3     3
# 2     4
# dtype: object

# %%
s2
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
import pandas as pd

sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Texas', 'Odaon', 'Tadas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)
df = pd.DataFrame([obj1],index = ["kk"])

# %%
df.T[35000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 35000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-139-0df4c0812a16> in <module>
# ----> 1 df.T[35000]
#
# ...

# %%
import math
math.isnan(obj2["California"])
# Out:
# True

# %%
import pandas as pd
d = {
    'd': 'Alice',
    'tt': 'Bob',
    'q': 'Rita',
    'fb': 'Molly',
    'z': 'Ryan'
}
S = pd.Series(d)

# %%
S.iloc[0:2]
# Out:
# d     Alice
# tt      Bob
# dtype: object

# %%
df
# Out:
#      0
# kk NaN

# %%
import pandas as pd
s1 = pd.Series({1: 'Alice', 2: 'Jack', 3: 'Molly'})
s2 = pd.Series({'Alice': 1, 'Jack': 2, 'Molly': 3})
s2.append(s1)
# Out:
# Alice        1
# Jack         2
# Molly        3
# 1        Alice
# 2         Jack
# 3        Molly
# dtype: object

# %%
print(i for i in s2)
# Out:
# <generator object <genexpr> at 0x0000020AB9154C10>

# %%
import pandas as pd

sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)

# %%
x = obj2['California']

# %%
obj2['California'] == None
# Out:
# False

# %%
import pandas as pd
s1 = pd.DataFrame({'k': 2, 'Jack': 3, 'Moll2': 3},index=[1,4,2])
s2 = pd.DataFrame({'k': 3, 'Jack': 2, 'Molly': 3},index=[1,5,3])
s1 = s1.add(s2,fill_value=0)
s1
# Out:
#    Jack  Moll2  Molly    k
# 1   5.0    3.0    3.0  5.0
# 2   3.0    3.0    NaN  2.0
# 3   2.0    NaN    3.0  3.0
# 4   3.0    3.0    NaN  2.0
# 5   2.0    NaN    3.0  3.0

# %%
s1.groupby('k').sum()
# Out:
#      Jack  Moll2  Molly
# k
# 2.0   6.0    6.0    0.0
# 3.0   4.0    0.0    6.0
# 5.0   5.0    3.0    3.0

# %%
import pandas as pd
s1 = pd.Series({'Alic0': 2, 'Jack': 3, 'Moll2': 3})
s1[0]
s1.index[0]
# Out:
# 'Alic0'

# %%
data = pd.DataFrame(np.arange(12).reshape((3,4)),
                   index = pd.Index(['a','c','c'],
                           name='state'),
                   columns=pd.Index(['one','two','three','four'],
                           name='number'))
data
# Out:
# number  one  two  three  four
# state
# a         0    1      2     3
# c         4    5      6     7
# c         8    9     10    11

# %%
data.unstack()
# Out:
# number  state
# one     a         0
#         c         4
#         c         8
# two     a         1
#         c         5
#         c         9
# three   a         2
#         c         6
#         c        10
# four    a         3
#         c         7
#         c        11
# dtype: int32

# %%
import numpy as np

a = np.arange(8)
b = a[4:6]
b[:] = 40
c = a[4] + a[6]
c
# Out:
# 46

# %%
import re
s = 'ABCAC'
re.match('A', s) ==True
# Out:
# False

# %%
import pandas as pd

df = pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'], index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'], columns = ['Grades'])
my_categories= pd.CategoricalDtype(categories = [A+])
grades = df['Grades'].astype(my_categories)
result = grades[(grades>'B') & (grades<'A')]

# %%
import matplotlib.pyplot as plt
import numpy as np

get_ipython().run_line_magic('matplotlib', 'notebook')

# generate 4 random variables from the random, gamma, exponential, and uniform distributions
x1 = np.random.normal(-2.5, 1, 10000)
x2 = np.random.gamma(2, 1.5, 10000)
x3 = np.random.exponential(2, 10000)+7
x4 = np.random.uniform(14,20, 10000)

# plot the histograms
plt.figure(figsize=(9,3))
plt.hist(x1, density=True, bins=20, alpha=0.5)
plt.hist(x2, density=True, bins=20, alpha=0.5)
plt.hist(x3, density=True, bins=20, alpha=0.5)
plt.hist(x4, density=True, bins=20, alpha=0.5);
plt.axis([-7,21,0,0.6])

plt.text(x1.mean()-1.5, 0.5, 'x1\nNormal')
plt.text(x2.mean()-1.5, 0.5, 'x2\nGamma')
plt.text(x3.mean()-1.5, 0.5, 'x3\nExponential')
plt.text(x4.mean()-1.5, 0.5, 'x4\nUniform')


# In[4]:


import matplotlib.animation as animation

n = 100

xs = [x1, x2, x3, x4]

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharey=True)
fig.suptitle('Sampling 4 Different Distributions')

axs = [ax1, ax2, ax3, ax4]


bins1 = np.arange(-7, 3, 0.1)
bins2 = np.arange(0, 10, 0.1)
bins3 = np.arange(6.9, 16.9, 0.1)
bins4 = np.arange(12, 22, 0.1)
binss = [bins1, bins2, bins3, bins4]

titles =['Normal', 'Gamma', 'Exponential', 'Uniform']
colors = ['red', 'blue', 'green', 'purple']


# create the function that will do the plotting, where curr is the current frame
def update(curr):
    # check if animation is at the last frame, and if so, stop the animation a
    if curr == n: 
        a.event_source.stop()
       
    for i in range(len(axs)):
        axs[i].cla()
        axs[i].hist(xs[i][:100*curr], density=True, bins=binss[i], color=colors[i])
        axs[i].axis([binss[i][0], binss[i][-1], 0, 0.6])
        axs[i].set_title(titles[i], fontsize='small')
        axs[i].set_ylabel('Frequency')
        axs[i].set_xlabel('Value')
        axs[i].annotate('n = {}'.format(100*curr), [binss[i][0] + 2*(binss[i][-1] - binss[i][0])/3, 0.5])
    plt.tight_layout() 
    plt.subplots_adjust(top=0.85)

    
a = animation.FuncAnimation(fig, update, interval=100)
# Out:
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(0,40,4)
y = np.arange(18,-2,-2)
c = x*y - 10*x

# %%
plt.plot(x,c)
plt.xlabel('quantity')
plt.ylabel('revenue')
max(c)
# Out:
# 32

# %%
g= np.arange(10)
d = len(c)
for i in np.arange(d-1):
    if i == 0:
        g[i] = c[i]
    g[i+1] = c[i+1]-c[i]

# %%
g = 18 - x
plt.plot(x,g)
plt.xlabel('Q')
plt.ylabel('MR')
# Out:
# Text(0, 0.5, 'MR')
